# %%
twitter_auth_token = 'ff08905efb96674b692dea9882b1dcff8c4c0f1c'

# %%
# !pip install pandas

# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'NODE_MAJOR' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# v18.18.0

# %%
filename = '-5 Oct-data.csv'
search_keyword = 'Kurikulum Merdeka since:2024-10-01 until:2024-10-06 lang:id'
limit = 2500

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# Tweet Harvest [v2.6.1]
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@825ab8183ab4d232adb5491066143d09"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] TimeoutError: page.click: Timeout 60000ms exceeded.
# Call log:
#   - waiting for locator('text=Retry')
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Filling in keywords: Kurikulum Merdeka since:2024-10-01 until:2024-10-06 lang:id
#
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 20
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 38
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 56
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 75
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 95
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 115
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 135
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 155
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 175
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 195
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 215
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 234
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 253
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 272
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 292
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 312
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 332
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 352
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 371
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 391
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 411
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 431
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 451
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 471
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 490
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 509
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 529
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 548
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 568
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 588
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3) (4) (5) (6)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 607
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 627
#
# -- Scrolling... (1) (2) (3) (4) (5) (6) (7) (8) (9)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 647
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 667
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 687
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 705
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 724
#
# -- Scrolling... (1)
#
# Your tweets saved to: d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\-5_Oct-data.csv
# Total tweets saved: 742
# Keywords: Kurikulum Merdeka since:2024-10-01 until:2024-10-06 lang:id
# Twitter Harvest v 2.6.1
#
# If you need help, please send this error screenshot to the maintainer, it was saved to "d:\Kuliah\SEMESTER 5\Deep Learning\PandemicInsights-Dataset\tweets-data\Error-13-11-2024_19-40-56.png"
